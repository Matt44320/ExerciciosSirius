# %% [markdown]
# <a href="https://colab.research.google.com/github/Matt44320/ExerciciosSirius/blob/main/Matthieu_MasterDS_Exercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios
#
# Vamos trabalhar com dados proveniente de duas fontes diferentes. Considere os dados do Índice de Desenvolvimento da Educação Básica (Ideb) disponíveis em [Ideb](https://basedosdados.org/dataset/br-inep-ideb?bdm_table=municipio) e os dados sobre Produto Interno Bruto (PIB) disponíveis em [PIB](https://basedosdados.org/dataset/br-ibge-pib?bdm_table=municipio).
#
# No conjunto de dados `ideb.csv` vamos selecionar as colunas `ano`, `id_municipio`, `media_saeb_mat`, `media_saeb_port` e `media_ideb` provenientes dos dados do Ideb, e as colunas `pib` e `impostos_liquidos` do `pib.csv`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ideb = '/content/drive/MyDrive/Colab Notebooks/Sirius_DS/ideb.csv'
pib = '/content/drive/MyDrive/Colab Notebooks/Sirius_DS/pib.csv'

# %%
import pandas as pd

df_ideb = pd.read_csv(ideb)
df_ideb.columns
df_ideb = df_ideb[['ano','id_municipio','nota_saeb_matematica', 'nota_saeb_lingua_portuguesa','ideb']]
df_ideb
# Out:
#          ano  id_municipio  nota_saeb_matematica  nota_saeb_lingua_portuguesa  \
# 0       2005       1200302                167.80                       165.60
# 1       2005       1200328                151.80                       149.60
# 2       2005       1200328                163.60                       155.80
# 3       2005       1200328                159.00                       153.39
# 4       2005       1200336                138.00                       134.19
# ...      ...           ...                   ...                          ...
# 294421  2019       3551108                229.75                       216.07
# 294422  2019       3551702                305.85                       296.39
# 294423  2019       3555406                230.69                       216.92
# 294424  2019       3555406                230.69                       216.92
# 294425  2019       1716653                243.69                       223.41
#
#         ideb
# 0        2.3
# 1        1.8
# 2        1.9
# 3        1.9
# 4        2.3
# ...      ...
# 294421   6.2
# 294422   6.2
# 294423   6.2
# 294424   6.2
# 294425   6.2
#
# [294426 rows x 5 columns]

# %%
df_pib = pd.read_csv(pib)
df_pib.columns
df_pib1 = df_pib[['pib', 'impostos_liquidos']]
df_pib
# Out:
#          ano  id_municipio           pib  impostos_liquidos            va  \
# 0       2002       1100015     111290995            7549266     103741729
# 1       2002       1100023     449592816           42665972     406926845
# 2       2002       1100031      31767520            1867935      29899585
# 3       2002       1100049     474443097           49622951     424820146
# 4       2002       1100056      79173614            8200971      70972643
# ...      ...           ...           ...                ...           ...
# 100181  2019       5222005     483663323           37741787     445921536
# 100182  2019       5222054     342355634           33561723     308793911
# 100183  2019       5222203     113668466            8405675     105262791
# 100184  2019       5222302     206971225            7933047     199038178
# 100185  2019       5300108  273613711477        30686607647  242927103829
#
#         va_agropecuaria  va_industria   va_servicos    va_adespss
# 0              27013223       9376871      24651113      42700523
# 1              28590178      99922936     161851549     116562182
# 2              10883801       1961907       5128876      11925001
# 3              32810376      98292764     175748703     117968303
# 4              11283793       6651475      25306009      27731366
# ...                 ...           ...           ...           ...
# 100181        174224615      26348404     175036109      70312408
# 100182        100351513      47140720     117133534      44168144
# 100183         24110657      16186594      33145548      31819993
# 100184        104542025      29867460      35312525      29316168
# 100185        992393584    9453608031  125261853488  107219248727
#
# [100186 rows x 9 columns]

# %% [markdown]
# ### Atividade 1: Selecione apenas as colunas `ano`, `id_municipio`, `media_saeb_mat`, `media_saeb_port` e `media_ideb` provenientes dos dados do Ideb, apenas para o ano de 2019 e agrupado por município.

# %%
df_ideb_2019 = df_ideb[df_ideb['ano'] == 2019]
df_ideb_2019
# Out:
#          ano  id_municipio  nota_saeb_matematica  nota_saeb_lingua_portuguesa  \
# 8947    2019       1200104                288.92                       263.10
# 8948    2019       1200104                254.78                       231.63
# 8949    2019       1200401                246.47                       228.63
# 8950    2019       1200450                256.67                       231.75
# 8951    2019       2701407                261.32                       223.47
# ...      ...           ...                   ...                          ...
# 294421  2019       3551108                229.75                       216.07
# 294422  2019       3551702                305.85                       296.39
# 294423  2019       3555406                230.69                       216.92
# 294424  2019       3555406                230.69                       216.92
# 294425  2019       1716653                243.69                       223.41
#
#         ideb
# 8947     8.1
# 8948     6.8
# 8949     6.7
# 8950     6.9
# 8951     7.0
# ...      ...
# 294421   6.2
# 294422   6.2
# 294423   6.2
# 294424   6.2
# 294425   6.2
#
# [40464 rows x 5 columns]

# %%
df_ideb_2019_municipio = df_ideb_2019.groupby(by = 'id_municipio').agg({'nota_saeb_matematica':'mean', 'nota_saeb_lingua_portuguesa' : 'mean','ideb':'mean'})
df_ideb_2019_municipio.rename(
    columns = {'nota_saeb_matematica':'media_saeb_mat', 'nota_saeb_lingua_portuguesa' : 'media_saeb_lingua_port', 'ideb':'media_ideb'}, inplace =True)
df_ideb_2019_municipio
# Out:
#               media_saeb_mat  media_saeb_lingua_port  media_ideb
# id_municipio
# 1100015           253.283750              242.246250    5.050000
# 1100023           248.223750              243.618750    4.762500
# 1100031           229.495000              221.500000    4.850000
# 1100049           259.150000              249.888889    5.200000
# 1100056           266.288571              254.334286    5.642857
# ...                      ...                     ...         ...
# 5222005           272.708571              262.805714    6.000000
# 5222054           271.685714              264.780000    5.828571
# 5222203           241.580000              231.394286    4.657143
# 5222302           269.355000              269.730000    4.950000
# 5300108           256.365000              252.218333    4.900000
#
# [5570 rows x 3 columns]

# %% [markdown]
# ### Atividade 2: Selecione as colunas `ano`, `id_municipio`, `pib` e `impostos_liquidos` dos dados do PIB, para o ano de 2019 e agrupado por município.

# %%
df_pib2 = df_pib[['ano','id_municipio','pib', 'impostos_liquidos']]
df_pib2_2019 = df_pib2[df_pib2['ano'] == 2019]
df_pib2_2019
# Out:
#          ano  id_municipio           pib  impostos_liquidos
# 94616   2019       1100015     495628767           29350985
# 94617   2019       1100023    2578829725          284397627
# 94618   2019       1100031     139959390            5997974
# 94619   2019       1100049    2260643565          253988284
# 94620   2019       1100056     506854457           76671376
# ...      ...           ...           ...                ...
# 100181  2019       5222005     483663323           37741787
# 100182  2019       5222054     342355634           33561723
# 100183  2019       5222203     113668466            8405675
# 100184  2019       5222302     206971225            7933047
# 100185  2019       5300108  273613711477        30686607647
#
# [5570 rows x 4 columns]

# %%
df_pib_2019_municipio = df_pib2_2019.groupby(by = 'id_municipio').agg({'pib':'mean', 'impostos_liquidos':'mean'})
df_pib_2019_municipio
# Out:
#                        pib  impostos_liquidos
# id_municipio
# 1100015       4.956288e+08       2.935098e+07
# 1100023       2.578830e+09       2.843976e+08
# 1100031       1.399594e+08       5.997974e+06
# 1100049       2.260644e+09       2.539883e+08
# 1100056       5.068545e+08       7.667138e+07
# ...                    ...                ...
# 5222005       4.836633e+08       3.774179e+07
# 5222054       3.423556e+08       3.356172e+07
# 5222203       1.136685e+08       8.405675e+06
# 5222302       2.069712e+08       7.933047e+06
# 5300108       2.736137e+11       3.068661e+10
#
# [5570 rows x 2 columns]

# %% [markdown]
# ### Atividade 3: Vamos juntar os dois DataFrames em um único. Para isso, vamos "unir" os dois dataframes pela variável `id_municipio`.

# %%
df = df_ideb_2019_municipio.merge(df_pib_2019_municipio, on = 'id_municipio', how = 'outer')
df
# Out:
#               media_saeb_mat  media_saeb_lingua_port  media_ideb  \
# id_municipio
# 1100015           253.283750              242.246250    5.050000
# 1100023           248.223750              243.618750    4.762500
# 1100031           229.495000              221.500000    4.850000
# 1100049           259.150000              249.888889    5.200000
# 1100056           266.288571              254.334286    5.642857
# ...                      ...                     ...         ...
# 5222005           272.708571              262.805714    6.000000
# 5222054           271.685714              264.780000    5.828571
# 5222203           241.580000              231.394286    4.657143
# 5222302           269.355000              269.730000    4.950000
# 5300108           256.365000              252.218333    4.900000
#
#                        pib  impostos_liquidos
# id_municipio
# 1100015       4.956288e+08       2.935098e+07
# 1100023       2.578830e+09       2.843976e+08
# 1100031       1.399594e+08       5.997974e+06
# 1100049       2.260644e+09       2.539883e+08
# 1100056       5.068545e+08       7.667138e+07
# ...                    ...                ...
# 5222005       4.836633e+08       3.774179e+07
# 5222054       3.423556e+08       3.356172e+07
# 5222203       1.136685e+08       8.405675e+06
# 5222302       2.069712e+08       7.933047e+06
# 5300108       2.736137e+11       3.068661e+10
#
# [5570 rows x 5 columns]

# %%
df.dtypes
# Out:
# media_saeb_mat            float64
# media_saeb_lingua_port    float64
# media_ideb                float64
# pib                       float64
# impostos_liquidos         float64
# dtype: object

# %% [markdown]
# ### Atividade 4:  Verifique se há dados faltantes, além disso verifique se há alguma coluna irrelevante. Se houver, descarte-a.

# %%
df.isna().sum()
# Out:
# media_saeb_mat            21
# media_saeb_lingua_port    21
# media_ideb                21
# pib                        0
# impostos_liquidos          0
# dtype: int64

# %%
df_semna = df.dropna()

df_semna.shape
# Out:
# (5549, 5)

# %% [markdown]
# ### Atividade 5: Quais são os tipos das variáveis do DataFrame?

# %% [markdown]
# São dados continuos.

# %% [markdown]
# ### Atividade 6: Observando as variáveis envolvidas, você acha que deve existir alguma correlação entre quais delas?
#
# Será que municípios com alta nota no Ideb possuem um PIB alto?

# %%
df_semna[['media_ideb', 'pib']].corr()
# Out:
#             media_ideb       pib
# media_ideb    1.000000  0.037105
# pib           0.037105  1.000000

# %% [markdown]
# ### O que significa a correlação das variáveis `id_municipio` e `ideb`?
#
# Significa que não ha correlação entre nota e PIB.

# %% [markdown]
# ### Atividade 7: Vamos importar os dados de [Estatística de Segurança Pública do Rio de Janeiro](https://basedosdados.org/dataset/br-isp-estatisticas-seguranca?bdm_table=taxa_evolucao_mensal_uf) e procurar por correlações entre algumas das colunas.

# %%
seg = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Sirius_DS/seg_rj.csv')
seg.corr(method= 'spearman')
# Out:
#                                  ano       mes  hom_doloso  lesao_corp_morte  \
# ano                         1.000000 -0.039640   -0.794997         -0.182688
# mes                        -0.039640  1.000000   -0.127381         -0.029673
# hom_doloso                 -0.794997 -0.127381    1.000000          0.278659
# lesao_corp_morte           -0.182688 -0.029673    0.278659          1.000000
# latrocinio                 -0.433580 -0.042646    0.602589          0.187286
# cvli                       -0.792489 -0.122955    0.998617          0.294053
# hom_por_interv_policial    -0.008083 -0.131089    0.227061          0.254990
# letalidade_violenta        -0.683444 -0.157678    0.938888          0.340909
# tentat_hom                  0.419777 -0.111790   -0.074373         -0.018490
# lesao_corp_dolosa          -0.605552 -0.020612    0.439327          0.029415
# estupro                     0.607657  0.044917   -0.590645         -0.276014
# hom_culposo                -0.802452  0.176267    0.617195          0.097258
# lesao_corp_culposa         -0.529684  0.191840    0.203247         -0.124904
# roubo_transeunte            0.490851 -0.018602   -0.202754          0.001747
# roubo_celular               0.439853 -0.005667   -0.126403          0.068882
# roubo_em_coletivo           0.285414 -0.020350    0.074408          0.218880
# roubo_rua                   0.557410 -0.010447   -0.233322          0.027813
# roubo_veiculo                    NaN       NaN         NaN               NaN
# roubo_carga                 0.396978  0.051727   -0.044331          0.045039
# roubo_comercio             -0.169806 -0.066267    0.341913          0.015824
# roubo_residencia           -0.852326 -0.034589    0.837576          0.236478
# roubo_banco                -0.376464 -0.113848    0.351415          0.177781
# roubo_cx_eletronico         0.174159 -0.124558    0.046215          0.071511
# roubo_conducao_saque       -0.710928 -0.035167    0.617201          0.168795
# roubo_apos_saque           -0.866958  0.052649    0.607495          0.053320
# roubo_bicicleta             0.457618  0.073892   -0.279171         -0.001939
# outros_roubos               0.076662 -0.124759    0.280153          0.151737
# total_roubos                0.322539 -0.067184    0.098076          0.118992
# furto_veiculos             -0.871640 -0.086369    0.804063          0.235178
# furto_transeunte            0.065405 -0.076914   -0.189643         -0.124148
# furto_coletivo              0.295005  0.086050   -0.402828         -0.212408
# furto_celular              -0.146278 -0.046573    0.001095          0.011605
# furto_bicicleta             0.369889  0.168159   -0.131845         -0.063219
# outros_furtos              -0.159712 -0.136782    0.065663         -0.064509
# total_furtos               -0.051018 -0.124975   -0.063953         -0.084147
# sequestro                  -0.255535  0.065577    0.203646          0.062792
# extorsao                    0.043502 -0.046056   -0.103964         -0.111555
# sequestro_relampago         0.358472  0.010993   -0.405395         -0.152927
# estelionato                 0.866111  0.051364   -0.826435         -0.255649
# apreensao_drogas            0.692608  0.006119   -0.584750         -0.180988
# posse_drogas                0.648592  0.051326   -0.531694         -0.146924
# trafico_drogas              0.730119 -0.040458   -0.470429         -0.157317
# apreensao_drogas_sem_autor -0.227995  0.012820    0.115113         -0.092867
# recuperacao_veiculos             NaN       NaN         NaN               NaN
# apf                         0.722262 -0.089166   -0.456035         -0.165055
# aaapai                      0.410552 -0.043174   -0.273360         -0.147356
# cmp                         0.365211  0.121727   -0.429450         -0.194238
# cmba                        0.451421 -0.004108   -0.129023         -0.001662
# ameaca                     -0.436808 -0.051777    0.199766         -0.092447
# pessoas_desaparecidas      -0.190954 -0.009800    0.075089         -0.064317
# encontro_cadaver           -0.848485 -0.144176    0.771263          0.193709
# encontro_ossada            -0.224156  0.041454    0.109701         -0.042204
# pol_militares_mortos_serv   0.024228 -0.057891    0.202137          0.117483
# pol_civis_mortos_serv       0.163659  0.080015   -0.101718         -0.218406
# registro_ocorrencias        0.439859 -0.020097   -0.283577         -0.105568
# fase                       -0.197525  0.046734    0.191467         -0.004715
#
#                             latrocinio      cvli  hom_por_interv_policial  \
# ano                          -0.433580 -0.792489                -0.008083
# mes                          -0.042646 -0.122955                -0.131089
# hom_doloso                    0.602589  0.998617                 0.227061
# lesao_corp_morte              0.187286  0.294053                 0.254990
# latrocinio                    1.000000  0.633127                 0.126139
# cvli                          0.633127  1.000000                 0.229438
# hom_por_interv_policial       0.126139  0.229438                 1.000000
# letalidade_violenta           0.587096  0.940526                 0.529131
# tentat_hom                    0.044404 -0.074098                -0.060869
# lesao_corp_dolosa             0.172995  0.430536                -0.438805
# estupro                      -0.358173 -0.595043                -0.427951
# hom_culposo                   0.367647  0.616015                 0.003759
# lesao_corp_culposa            0.105272  0.196714                -0.542526
# roubo_transeunte              0.100010 -0.194271                 0.035103
# roubo_celular                 0.032399 -0.117470                 0.541357
# roubo_em_coletivo             0.211531  0.085039                 0.618653
# roubo_rua                     0.065760 -0.224531                 0.184995
# roubo_veiculo                      NaN       NaN                      NaN
# roubo_carga                   0.057328 -0.039957                 0.246759
# roubo_comercio                0.325127  0.345480                -0.164120
# roubo_residencia              0.506641  0.839177                 0.106133
# roubo_banco                   0.260263  0.355372                -0.034924
# roubo_cx_eletronico           0.093454  0.050680                 0.195837
# roubo_conducao_saque          0.291994  0.613226                 0.135740
# roubo_apos_saque              0.271061  0.601036                -0.039497
# roubo_bicicleta              -0.144146 -0.274053                 0.315130
# outros_roubos                 0.257899  0.287888                 0.540610
# total_roubos                  0.268082  0.107966                 0.362518
# furto_veiculos                0.511564  0.804885                 0.102719
# furto_transeunte             -0.057992 -0.192850                -0.583489
# furto_coletivo               -0.149395 -0.406066                -0.599423
# furto_celular                 0.042017 -0.002366                -0.171852
# furto_bicicleta              -0.024476 -0.126771                 0.509291
# outros_furtos                 0.073343  0.061866                -0.446098
# total_furtos                  0.028831 -0.067105                -0.500846
# sequestro                     0.121145  0.205400                -0.066423
# extorsao                     -0.049728 -0.109979                -0.332350
# sequestro_relampago          -0.260816 -0.409746                -0.315819
# estelionato                  -0.504808 -0.827753                -0.181168
# apreensao_drogas             -0.348724 -0.586030                -0.288788
# posse_drogas                 -0.346893 -0.533920                -0.316252
# trafico_drogas               -0.215551 -0.468765                -0.149151
# apreensao_drogas_sem_autor    0.059717  0.109470                -0.351814
# recuperacao_veiculos               NaN       NaN                      NaN
# apf                          -0.220419 -0.455667                -0.180521
# aaapai                       -0.089504 -0.274524                -0.454111
# cmp                          -0.172835 -0.427027                -0.368168
# cmba                          0.013662 -0.124805                 0.181322
# ameaca                        0.020468  0.188524                -0.584047
# pessoas_desaparecidas         0.081481  0.071023                -0.567050
# encontro_cadaver              0.408382  0.767163                 0.021605
# encontro_ossada               0.021470  0.103854                 0.002970
# pol_militares_mortos_serv     0.038552  0.200591                 0.141050
# pol_civis_mortos_serv        -0.087784 -0.109337                 0.023824
# registro_ocorrencias         -0.024232 -0.281478                -0.331946
# fase                          0.188828  0.192077                -0.083722
#
#                             letalidade_violenta  tentat_hom  \
# ano                                   -0.683444    0.419777
# mes                                   -0.157678   -0.111790
# hom_doloso                             0.938888   -0.074373
# lesao_corp_morte                       0.340909   -0.018490
# latrocinio                             0.587096    0.044404
# cvli                                   0.940526   -0.074098
# hom_por_interv_policial                0.529131   -0.060869
# letalidade_violenta                    1.000000   -0.070437
# tentat_hom                            -0.070437    1.000000
# lesao_corp_dolosa                      0.225388   -0.027126
# estupro                               -0.653515    0.426429
# hom_culposo                            0.524956   -0.425017
# lesao_corp_culposa                    -0.014330   -0.114323
# roubo_transeunte                      -0.143240    0.613977
# roubo_celular                          0.087595    0.331547
# roubo_em_coletivo                      0.285778    0.249372
# roubo_rua                             -0.119140    0.589490
# roubo_veiculo                               NaN         NaN
# roubo_carga                            0.058040    0.531238
# roubo_comercio                         0.248368    0.488332
# roubo_residencia                       0.759309   -0.250334
# roubo_banco                            0.296281   -0.021300
# roubo_cx_eletronico                    0.101824    0.001486
# roubo_conducao_saque                   0.578978   -0.313872
# roubo_apos_saque                       0.504219   -0.405965
# roubo_bicicleta                       -0.103423   -0.369234
# outros_roubos                          0.446030    0.285632
# total_roubos                           0.227858    0.632117
# furto_veiculos                         0.727349   -0.270099
# furto_transeunte                      -0.363329    0.315530
# furto_coletivo                        -0.549204    0.391726
# furto_celular                         -0.059206   -0.047381
# furto_bicicleta                        0.160799   -0.214223
# outros_furtos                         -0.095599    0.223000
# total_furtos                          -0.225289    0.235241
# sequestro                              0.154321   -0.113334
# extorsao                              -0.193350    0.183740
# sequestro_relampago                   -0.451879    0.198869
# estelionato                           -0.776455    0.302705
# apreensao_drogas                      -0.600929    0.588745
# posse_drogas                          -0.583271    0.501183
# trafico_drogas                        -0.441712    0.651765
# apreensao_drogas_sem_autor            -0.052151    0.290101
# recuperacao_veiculos                        NaN         NaN
# apf                                   -0.438375    0.629342
# aaapai                                -0.403019    0.640263
# cmp                                   -0.490651    0.442030
# cmba                                   0.003789    0.575950
# ameaca                                -0.034444    0.051438
# pessoas_desaparecidas                 -0.127541    0.291901
# encontro_cadaver                       0.668729   -0.207211
# encontro_ossada                        0.086651   -0.117285
# pol_militares_mortos_serv              0.235289    0.194882
# pol_civis_mortos_serv                 -0.104029   -0.084723
# registro_ocorrencias                  -0.342171    0.702333
# fase                                   0.165897    0.168033
#
#                             lesao_corp_dolosa  ...       cmp      cmba  \
# ano                                 -0.605552  ...  0.365211  0.451421
# mes                                 -0.020612  ...  0.121727 -0.004108
# hom_doloso                           0.439327  ... -0.429450 -0.129023
# lesao_corp_morte                     0.029415  ... -0.194238 -0.001662
# latrocinio                           0.172995  ... -0.172835  0.013662
# cvli                                 0.430536  ... -0.427027 -0.124805
# hom_por_interv_policial             -0.438805  ... -0.368168  0.181322
# letalidade_violenta                  0.225388  ... -0.490651  0.003789
# tentat_hom                          -0.027126  ...  0.442030  0.575950
# lesao_corp_dolosa                    1.000000  ...  0.000117 -0.291923
# estupro                              0.045954  ...  0.569119  0.267114
# hom_culposo                          0.508854  ... -0.356073 -0.411910
# lesao_corp_culposa                   0.766176  ...  0.207517 -0.274489
# roubo_transeunte                    -0.262633  ...  0.345449  0.585643
# roubo_celular                       -0.681540  ...  0.096765  0.525982
# roubo_em_coletivo                   -0.536602  ... -0.122458  0.446732
# roubo_rua                           -0.407370  ...  0.289846  0.652999
# roubo_veiculo                             NaN  ...       NaN       NaN
# roubo_carga                         -0.414974  ...  0.321594  0.595461
# roubo_comercio                       0.247466  ...  0.504281  0.356344
# roubo_residencia                     0.511862  ... -0.300576 -0.243530
# roubo_banco                          0.244735  ... -0.084373 -0.025284
# roubo_cx_eletronico                 -0.183783  ... -0.275183 -0.035150
# roubo_conducao_saque                 0.365102  ... -0.208867 -0.257634
# roubo_apos_saque                     0.566728  ... -0.184279 -0.348692
# roubo_bicicleta                     -0.337562  ... -0.225075  0.207506
# outros_roubos                       -0.376909  ...  0.060671  0.539607
# total_roubos                        -0.359644  ...  0.257600  0.660629
# furto_veiculos                       0.500993  ... -0.298228 -0.352096
# furto_transeunte                     0.427214  ...  0.294022 -0.074614
# furto_coletivo                       0.232419  ...  0.603326  0.137560
# furto_celular                        0.270848  ... -0.231223 -0.207115
# furto_bicicleta                     -0.222457  ...  0.023816  0.639452
# outros_furtos                        0.568283  ...  0.251123 -0.065631
# total_furtos                         0.483273  ...  0.162777 -0.146915
# sequestro                            0.141625  ... -0.133981 -0.122699
# extorsao                             0.211556  ...  0.399947  0.075484
# sequestro_relampago                 -0.078500  ...  0.348564  0.116553
# estelionato                         -0.416025  ...  0.519996  0.293621
# apreensao_drogas                    -0.215263  ...  0.718171  0.440216
# posse_drogas                        -0.120451  ...  0.639098  0.331242
# trafico_drogas                      -0.275833  ...  0.711346  0.544147
# apreensao_drogas_sem_autor           0.422506  ...  0.431691  0.047212
# recuperacao_veiculos                      NaN  ...       NaN       NaN
# apf                                 -0.206739  ...  0.713812  0.508231
# aaapai                               0.165573  ...  0.732979  0.438838
# cmp                                  0.000117  ...  1.000000  0.542331
# cmba                                -0.291923  ...  0.542331  1.000000
# ameaca                               0.890175  ...  0.227007 -0.204284
# pessoas_desaparecidas                0.651756  ...  0.283483 -0.032968
# encontro_cadaver                     0.595812  ... -0.282237 -0.298283
# encontro_ossada                      0.104105  ...  0.153824 -0.040872
# pol_militares_mortos_serv           -0.006000  ... -0.034310  0.244358
# pol_civis_mortos_serv               -0.232360  ... -0.131636 -0.102355
# registro_ocorrencias                 0.090855  ...  0.701707  0.556333
# fase                                 0.191462  ...  0.132348  0.174918
#
#                               ameaca  pessoas_desaparecidas  encontro_cadaver  \
# ano                        -0.436808              -0.190954         -0.848485
# mes                        -0.051777              -0.009800         -0.144176
# hom_doloso                  0.199766               0.075089          0.771263
# lesao_corp_morte           -0.092447              -0.064317          0.193709
# latrocinio                  0.020468               0.081481          0.408382
# cvli                        0.188524               0.071023          0.767163
# hom_por_interv_policial    -0.584047              -0.567050          0.021605
# letalidade_violenta        -0.034444              -0.127541          0.668729
# tentat_hom                  0.051438               0.291901         -0.207211
# lesao_corp_dolosa           0.890175               0.651756          0.595812
# estupro                     0.255940               0.327507         -0.548785
# hom_culposo                 0.330800               0.068871          0.581935
# lesao_corp_culposa          0.843263               0.599984          0.404632
# roubo_transeunte           -0.140654               0.162981         -0.440260
# roubo_celular              -0.676365              -0.391657         -0.337599
# roubo_em_coletivo          -0.658272              -0.426323         -0.259386
# roubo_rua                  -0.309517               0.018004         -0.500524
# roubo_veiculo                    NaN                    NaN               NaN
# roubo_carga                -0.457823              -0.202368         -0.154091
# roubo_comercio              0.294455               0.346852          0.284032
# roubo_residencia            0.320781               0.130153          0.750910
# roubo_banco                 0.202034               0.182839          0.326966
# roubo_cx_eletronico        -0.261656              -0.179949         -0.183415
# roubo_conducao_saque        0.234209               0.000413          0.613792
# roubo_apos_saque            0.490005               0.244205          0.682453
# roubo_bicicleta            -0.332292              -0.250193         -0.282065
# outros_roubos              -0.482338              -0.323831          0.033603
# total_roubos               -0.347178              -0.043832         -0.222030
# furto_veiculos              0.336187               0.188862          0.764314
# furto_transeunte            0.597229               0.665126         -0.028126
# furto_coletivo              0.489737               0.610876         -0.263396
# furto_celular               0.303404               0.352189          0.051889
# furto_bicicleta            -0.229946              -0.194006         -0.319891
# outros_furtos               0.695361               0.659885          0.170768
# total_furtos                0.624225               0.662893          0.055914
# sequestro                   0.088787               0.079850          0.230502
# extorsao                    0.296254               0.299288         -0.023598
# sequestro_relampago         0.082338               0.043277         -0.353957
# estelionato                -0.199225              -0.006444         -0.728826
# apreensao_drogas            0.014278               0.189418         -0.466880
# posse_drogas                0.058178               0.201220         -0.332453
# trafico_drogas             -0.075406               0.128693         -0.423997
# apreensao_drogas_sem_autor  0.496155               0.434925          0.297249
# recuperacao_veiculos             NaN                    NaN               NaN
# apf                        -0.009940               0.144285         -0.427203
# aaapai                      0.353927               0.436803         -0.149612
# cmp                         0.227007               0.283483         -0.282237
# cmba                       -0.204284              -0.032968         -0.298283
# ameaca                      1.000000               0.780006          0.418937
# pessoas_desaparecidas       0.780006               1.000000          0.256930
# encontro_cadaver            0.418937               0.256930          1.000000
# encontro_ossada             0.123005               0.084734          0.205277
# pol_militares_mortos_serv  -0.050837               0.000619          0.024869
# pol_civis_mortos_serv      -0.228815              -0.141895         -0.145828
# registro_ocorrencias        0.278402               0.490680         -0.311053
# fase                        0.186591               0.184167          0.167177
#
#                             encontro_ossada  pol_militares_mortos_serv  \
# ano                               -0.224156                   0.024228
# mes                                0.041454                  -0.057891
# hom_doloso                         0.109701                   0.202137
# lesao_corp_morte                  -0.042204                   0.117483
# latrocinio                         0.021470                   0.038552
# cvli                               0.103854                   0.200591
# hom_por_interv_policial            0.002970                   0.141050
# letalidade_violenta                0.086651                   0.235289
# tentat_hom                        -0.117285                   0.194882
# lesao_corp_dolosa                  0.104105                  -0.006000
# estupro                           -0.184412                  -0.125489
# hom_culposo                        0.129602                  -0.052970
# lesao_corp_culposa                 0.109967                  -0.017039
# roubo_transeunte                  -0.235887                   0.270783
# roubo_celular                     -0.001853                   0.234657
# roubo_em_coletivo                 -0.119588                   0.287129
# roubo_rua                         -0.231190                   0.297110
# roubo_veiculo                           NaN                        NaN
# roubo_carga                       -0.050945                   0.286200
# roubo_comercio                     0.104542                   0.166524
# roubo_residencia                   0.225794                   0.178887
# roubo_banco                        0.082222                   0.040182
# roubo_cx_eletronico               -0.182389                  -0.023622
# roubo_conducao_saque               0.253697                   0.164463
# roubo_apos_saque                   0.238531                  -0.156181
# roubo_bicicleta                    0.002013                   0.036103
# outros_roubos                      0.056676                   0.297739
# total_roubos                      -0.104044                   0.321168
# furto_veiculos                     0.190865                  -0.031898
# furto_transeunte                  -0.147407                   0.020375
# furto_coletivo                    -0.090934                   0.000557
# furto_celular                     -0.093100                   0.047189
# furto_bicicleta                    0.000431                   0.103619
# outros_furtos                     -0.028724                  -0.001023
# total_furtos                      -0.107520                  -0.025493
# sequestro                         -0.039348                   0.113490
# extorsao                           0.083316                   0.018848
# sequestro_relampago               -0.083644                  -0.028593
# estelionato                       -0.106142                  -0.077663
# apreensao_drogas                   0.010932                  -0.070810
# posse_drogas                       0.069771                  -0.185796
# trafico_drogas                     0.035835                   0.056330
# apreensao_drogas_sem_autor         0.217147                  -0.071655
# recuperacao_veiculos                    NaN                        NaN
# apf                                0.043265                   0.027226
# aaapai                             0.042338                  -0.013674
# cmp                                0.153824                  -0.034310
# cmba                              -0.040872                   0.244358
# ameaca                             0.123005                  -0.050837
# pessoas_desaparecidas              0.084734                   0.000619
# encontro_cadaver                   0.205277                   0.024869
# encontro_ossada                    1.000000                  -0.017122
# pol_militares_mortos_serv         -0.017122                   1.000000
# pol_civis_mortos_serv             -0.015992                  -0.089936
# registro_ocorrencias              -0.111718                   0.089348
# fase                              -0.016867                   0.041776
#
#                             pol_civis_mortos_serv  registro_ocorrencias  \
# ano                                      0.163659              0.439859
# mes                                      0.080015             -0.020097
# hom_doloso                              -0.101718             -0.283577
# lesao_corp_morte                        -0.218406             -0.105568
# latrocinio                              -0.087784             -0.024232
# cvli                                    -0.109337             -0.281478
# hom_por_interv_policial                  0.023824             -0.331946
# letalidade_violenta                     -0.104029             -0.342171
# tentat_hom                              -0.084723              0.702333
# lesao_corp_dolosa                       -0.232360              0.090855
# estupro                                 -0.075787              0.649680
# hom_culposo                              0.024905             -0.364317
# lesao_corp_culposa                      -0.166954              0.158820
# roubo_transeunte                        -0.019963              0.795983
# roubo_celular                            0.090963              0.077062
# roubo_em_coletivo                        0.003613              0.160134
# roubo_rua                               -0.022050              0.710180
# roubo_veiculo                                 NaN                   NaN
# roubo_carga                              0.006411              0.323027
# roubo_comercio                          -0.161624              0.442737
# roubo_residencia                        -0.145710             -0.288476
# roubo_banco                             -0.058143             -0.008426
# roubo_cx_eletronico                      0.000419              0.023600
# roubo_conducao_saque                    -0.208138             -0.358266
# roubo_apos_saque                        -0.149974             -0.347561
# roubo_bicicleta                         -0.023476             -0.283934
# outros_roubos                            0.060197             -0.044740
# total_roubos                            -0.023273              0.560111
# furto_veiculos                          -0.162364             -0.273417
# furto_transeunte                        -0.169422              0.674920
# furto_coletivo                          -0.141278              0.786116
# furto_celular                           -0.140434              0.298630
# furto_bicicleta                         -0.042230             -0.060601
# outros_furtos                           -0.252359              0.550031
# total_furtos                            -0.219093              0.629806
# sequestro                                0.060255             -0.165283
# extorsao                                -0.007137              0.389144
# sequestro_relampago                     -0.103062              0.347529
# estelionato                              0.077998              0.511722
# apreensao_drogas                        -0.164966              0.609223
# posse_drogas                            -0.175173              0.570999
# trafico_drogas                          -0.058478              0.679489
# apreensao_drogas_sem_autor              -0.155534              0.451371
# recuperacao_veiculos                          NaN                   NaN
# apf                                     -0.114518              0.693913
# aaapai                                  -0.168956              0.796135
# cmp                                     -0.131636              0.701707
# cmba                                    -0.102355              0.556333
# ameaca                                  -0.228815              0.278402
# pessoas_desaparecidas                   -0.141895              0.490680
# encontro_cadaver                        -0.145828             -0.311053
# encontro_ossada                         -0.015992             -0.111718
# pol_militares_mortos_serv               -0.089936              0.089348
# pol_civis_mortos_serv                    1.000000             -0.176142
# registro_ocorrencias                    -0.176142              1.000000
# fase                                    -0.094753              0.186591
#
#                                 fase
# ano                        -0.197525
# mes                         0.046734
# hom_doloso                  0.191467
# lesao_corp_morte           -0.004715
# latrocinio                  0.188828
# cvli                        0.192077
# hom_por_interv_policial    -0.083722
# letalidade_violenta         0.165897
# tentat_hom                  0.168033
# lesao_corp_dolosa           0.191462
# estupro                     0.014003
# hom_culposo                 0.164392
# lesao_corp_culposa          0.190245
# roubo_transeunte            0.139715
# roubo_celular              -0.064531
# roubo_em_coletivo          -0.061792
# roubo_rua                   0.101971
# roubo_veiculo                    NaN
# roubo_carga                 0.024656
# roubo_comercio              0.184467
# roubo_residencia            0.154055
# roubo_banco                 0.099413
# roubo_cx_eletronico        -0.130919
# roubo_conducao_saque        0.110939
# roubo_apos_saque            0.160426
# roubo_bicicleta            -0.044439
# outros_roubos               0.026482
# total_roubos                0.161022
# furto_veiculos              0.178983
# furto_transeunte            0.187809
# furto_coletivo              0.120540
# furto_celular               0.151892
# furto_bicicleta             0.054995
# outros_furtos               0.189636
# total_furtos                0.187200
# sequestro                   0.016744
# extorsao                    0.020703
# sequestro_relampago         0.023355
# estelionato                -0.196941
# apreensao_drogas           -0.066662
# posse_drogas               -0.113670
# trafico_drogas             -0.013116
# apreensao_drogas_sem_autor  0.093019
# recuperacao_veiculos             NaN
# apf                        -0.023449
# aaapai                      0.140298
# cmp                         0.132348
# cmba                        0.174918
# ameaca                      0.186591
# pessoas_desaparecidas       0.184167
# encontro_cadaver            0.167177
# encontro_ossada            -0.016867
# pol_militares_mortos_serv   0.041776
# pol_civis_mortos_serv      -0.094753
# registro_ocorrencias        0.186591
# fase                        1.000000
#
# [56 rows x 56 columns]

# %% [markdown]
# ### Atividade 8: Selecione os dados apenas para o ano de 2020 e apenas as colunas `mês`, `hom_doloso, lesao_corp_morte, latrocinio, cvli, hom_por_interv_policial`, e `trafico_drogas`

# %%
seg_2020 = seg.loc[seg['ano'] == 2020, ['mes', 'hom_doloso', 'lesao_corp_morte', 'latrocinio', 'cvli', 'hom_por_interv_policial', 'trafico_drogas']]
seg_2020
# Out:
#      mes  hom_doloso  lesao_corp_morte  latrocinio  cvli  \
# 204    1        2.07              0.02        0.05  2.14
# 205    2        1.88              0.01        0.06  1.95
# 206    3        2.16              0.01        0.05  2.22
# 207    4        1.80              0.03        0.03  1.86
# 208    5        1.57              0.00        0.03  1.61
# 209    6        1.49              0.01        0.01  1.52
# 210    7        1.48              0.02        0.04  1.54
# 211    8        1.50              0.01        0.07  1.58
# 212    9        1.37              0.02        0.04  1.43
# 213   10        1.59              0.01        0.03  1.63
# 214   11        1.87              0.01        0.05  1.93
# 215   12        1.63              0.02        0.05  1.69
#
#      hom_por_interv_policial  trafico_drogas
# 204                     0.90            5.06
# 205                     0.95            5.06
# 206                     0.66            4.70
# 207                     1.03            5.29
# 208                     0.75            5.39
# 209                     0.20            4.71
# 210                     0.30            5.15
# 211                     0.29            5.28
# 212                     0.31            5.12
# 213                     0.83            5.23
# 214                     0.47            4.71
# 215                     0.48            4.75

# %%
seg_2020.corr(method = 'spearman')
# Out:
#                               mes  hom_doloso  lesao_corp_morte  latrocinio  \
# mes                      1.000000   -0.468531          0.011427   -0.061063
# hom_doloso              -0.468531    1.000000         -0.064753    0.423852
# lesao_corp_morte         0.011427   -0.064753          1.000000   -0.031304
# latrocinio              -0.061063    0.423852         -0.031304    1.000000
# cvli                    -0.461538    0.993007         -0.026663    0.456180
# hom_por_interv_policial -0.489510    0.664336          0.159977    0.017960
# trafico_drogas          -0.028070   -0.396494          0.053513   -0.252321
#
#                              cvli  hom_por_interv_policial  trafico_drogas
# mes                     -0.461538                -0.489510       -0.028070
# hom_doloso               0.993007                 0.664336       -0.396494
# lesao_corp_morte        -0.026663                 0.159977        0.053513
# latrocinio               0.456180                 0.017960       -0.252321
# cvli                     1.000000                 0.678322       -0.357897
# hom_por_interv_policial  0.678322                 1.000000        0.249124
# trafico_drogas          -0.357897                 0.249124        1.000000

# %% [markdown]
# **Correlações fortes :**
#
# A Taxa de Morte por intervenção de agente do Estado por 100 mil habitantes e Taxa de Homicídio doloso por 100 mil habitantes têm uma correlação forte positiva de aproximadamente 0.66.
#
# Taxa de Latrocínio (roubo seguido de morte) por 100 mil habitantes e a Taxa de Crimes Violentos Letais Intencionais por 100 mil habitantes também demonstram uma correlação positiva forte de 0.46.
#
# **Correlações muito fortes :**
#
# A correlação mais forte do dataset está entre a Taxa de Homicídio doloso por 100 mil habitantes e a Taxa de Crimes Violentos Letais Intencionais por 100 mil habitantes com um coeficiente de 0.99. Isso significa que quando aumenta a taxa de homicidio doloso, a tendência é que a taxa de crimes violentos letais aumentem também.

# %% [markdown]
# ### Verificando se a tendência de correlação em 2020 se confirma com todos os anos :

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax = sns.scatterplot(data = seg,x = 'cvli', y = 'hom_doloso').set_title(
    'Relação entre Taxa de homicidio doloso vs Taxa de crimes violentos intencionais',fontdict = { 'fontsize': 15})
sns.set( style = "white") 
plt.xlabel('Taxa de Crimes Violentos Letais Intencionais')
plt.ylabel('Taxa de Homicídio doloso')

ax;
